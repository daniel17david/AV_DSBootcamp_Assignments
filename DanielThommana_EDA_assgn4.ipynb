# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings(action = 'ignore')

# %%
data = pd.read_csv('lead.csv')

# %%
data.head()
# Out:
#          ID  Gender  Age  ... Avg_Account_Balance Is_Active Is_Lead
# 0  NNVBBKZB  Female   73  ...             1045696        No       0
# 1  IDD62UNG  Female   30  ...              581988        No       0
# 2  HD3DSEMC  Female   56  ...             1484315       Yes       0
# 3  BF3NC7KV    Male   34  ...              470454        No       0
# 4  TEASRWXV  Female   30  ...              886787        No       0
#
# [5 rows x 11 columns]

# %% [markdown]
# ### Q1 : Provide Propoer encoding to all the required features in the dataset ?

# %%
df = pd.get_dummies(data=data,  columns=['Gender','Occupation','Channel_Code','Credit_Product','Is_Active'])
df.head()
# Out:
#          ID  Age Region_Code  ...  Credit_Product_Yes  Is_Active_No  Is_Active_Yes
# 0  NNVBBKZB   73       RG268  ...                   0             1              0
# 1  IDD62UNG   30       RG277  ...                   0             1              0
# 2  HD3DSEMC   56       RG268  ...                   0             0              1
# 3  BF3NC7KV   34       RG270  ...                   0             1              0
# 4  TEASRWXV   30       RG282  ...                   0             1              0
#
# [5 rows x 20 columns]

# %%
df.dtypes
# Out:
# ID                          object
# Age                          int64
# Region_Code                 object
# Vintage                      int64
# Avg_Account_Balance          int64
# Is_Lead                      int64
# Gender_Female                uint8
# Gender_Male                  uint8
# Occupation_Entrepreneur      uint8
# Occupation_Other             uint8
# Occupation_Salaried          uint8
# Occupation_Self_Employed     uint8
# Channel_Code_X1              uint8
# Channel_Code_X2              uint8
# Channel_Code_X3              uint8
# Channel_Code_X4              uint8
# Credit_Product_No            uint8
# Credit_Product_Yes           uint8
# Is_Active_No                 uint8
# Is_Active_Yes                uint8
# dtype: object

# %%
# isolating numerical datatypes
numerical = df.select_dtypes(include=['int64','uint8'])[:]
numerical.dtypes
# Out:
# Age                         int64
# Vintage                     int64
# Avg_Account_Balance         int64
# Is_Lead                     int64
# Gender_Female               uint8
# Gender_Male                 uint8
# Occupation_Entrepreneur     uint8
# Occupation_Other            uint8
# Occupation_Salaried         uint8
# Occupation_Self_Employed    uint8
# Channel_Code_X1             uint8
# Channel_Code_X2             uint8
# Channel_Code_X3             uint8
# Channel_Code_X4             uint8
# Credit_Product_No           uint8
# Credit_Product_Yes          uint8
# Is_Active_No                uint8
# Is_Active_Yes               uint8
# dtype: object

# %% [markdown]
# ### Q2 : Plot correlation matrix for the data ?

# %%
# calculating correlation
correlation = numerical.dropna().corr()
correlation
# Out:
#                                Age   Vintage  ...  Is_Active_No  Is_Active_Yes
# Age                       1.000000  0.631242  ...     -0.218770       0.218770
# Vintage                   0.631242  1.000000  ...     -0.209356       0.209356
# Avg_Account_Balance       0.145232  0.167433  ...     -0.076637       0.076637
# Is_Lead                   0.230814  0.279642  ...     -0.085723       0.085723
# Gender_Female            -0.152076 -0.146380  ...      0.064207      -0.064207
# Gender_Male               0.152076  0.146380  ...     -0.064207       0.064207
# Occupation_Entrepreneur   0.028095  0.073515  ...     -0.010250       0.010250
# Occupation_Other          0.394834  0.155663  ...     -0.028119       0.028119
# Occupation_Salaried      -0.563227 -0.410109  ...      0.207638      -0.207638
# Occupation_Self_Employed  0.152652  0.221024  ...     -0.164130       0.164130
# Channel_Code_X1          -0.664600 -0.571828  ...      0.292109      -0.292109
# ...

# %% [markdown]
# ### Q3: Identify the most correlated features in the data ?

# %%
plt.figure(dpi=130)
sns.heatmap(correlation, linewidths = 1,cmap='Blues')

# %% [markdown]
# ## Age and Vintage have  A strong positive relationship
# ## Age and Occupation_Salaried have  A strong negative relationship
# ## Channel_Code_X1 and Occupation_Salaried have A strong positive relationship
# ## Channel_Code_X1 and Age have  A strong negative relationship

# %% [markdown]
# ### Q 4: Plot paired plot for right set of features ?

# %%
similar = ['Age','Vintage']

# %%
# scatter plot for transactional variables
plt.figure(dpi=140)
sns.pairplot(numerical[similar])

# %%
plt.figure(dpi=140)
sns.jointplot('Age','Vintage', data= numerical[similar], kind='reg',line_kws={"color":"red"} )
plt.plot()
# Out:
# []

# %%
similar2 = ['Age','Occupation_Salaried']

# %%
# scatter plot for transactional variables
plt.figure(dpi=140)
sns.pairplot(numerical[similar2])

# %%
plt.figure(dpi=140)
sns.jointplot('Age','Occupation_Salaried', data= numerical[similar2], kind='reg',line_kws={"color":"red"} )
plt.plot()
# Out:
# []

# %%
similar3 = ['Channel_Code_X1','Occupation_Salaried']

# %%
# scatter plot for transactional variables
plt.figure(dpi=140)
sns.pairplot(numerical[similar3])

# %%
plt.figure(dpi=140)
sns.jointplot('Channel_Code_X1','Occupation_Salaried', data= numerical[similar3], kind='reg',line_kws={"color":"red"} )
plt.plot()
# Out:
# []

# %%
similar4 = ['Channel_Code_X1','Age']

# %%
# scatter plot for transactional variables
plt.figure(dpi=140)
sns.pairplot(numerical[similar4])

# %%
plt.figure(dpi=140)
sns.jointplot('Channel_Code_X1','Age', data= numerical[similar4], kind='reg',line_kws={"color":"red"} )
plt.plot()
# Out:
# []
